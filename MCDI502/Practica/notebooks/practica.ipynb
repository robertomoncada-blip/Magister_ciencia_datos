# %%
from pyspark.sql import SparkSession

# Crear sesion spark
#spark = SparkSession.builder \
#.master("local[*]") \
#.appName("MiPrimerSpark") \
#.getOrCreate()


#import os
#rint("JAVA_HOME =", os.environ.get("JAVA_HOME"))
# Out:
# JAVA_HOME = None
